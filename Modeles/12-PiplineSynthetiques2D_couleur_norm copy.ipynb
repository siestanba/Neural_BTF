# %% [markdown]
# ## Code produit avec l'article:
# https://medium.com/h7w/implementing-a-variational-autoencoder-with-keras-e19d7140ad90

# %% [markdown]
# ### Ce modèle est spécifique aux données de la scène 3D avec un angle de caméra fixe
# #### Et les couleurs ont été normalisées

# %%
from keras.layers import Conv1D, Conv2D, Input, Flatten, Dense, MaxPooling1D, MaxPooling2D, BatchNormalization, Concatenate
from keras.optimizers import Adam
import matplotlib.pyplot as plt
from keras.models import Model
import tensorflow as tf
from PIL import Image
import copy
import numpy as np
import keras
import os
import re

# %%
# Fonction pour calculer les coordonées stéréographiques

def stereo(theta, phi):
    x = np.sin(theta) * np.cos(phi)
    y = np.sin(theta) * np.sin(phi)
    z = np.cos(theta)

    # Projection sur x y
    px = x / (1 + z + 1e-8)
    py = y / (1 + z + 1e-8)
    return px, py

# %% [markdown]
# # Importation des images

# %%
# Dossier contenant les images
repertoire = "../Render/captures"
img_width, img_height = 50, 50

# Expression pour extraire les infos du nom de fichier
#pattern = re.compile(r"img_tv(\d+)_pv(\d+)_tl(\d+)_pl(\d+)\.png") #all
pattern = re.compile(r"img_tv0_pv0_tl(\d+)_pl(\d+)\.jpg") #les images avec tv = 45 (la latitude moyenne)

# Stockage des résultats
images_info = []

for nom_fichier in os.listdir(repertoire):
    if nom_fichier.endswith(".jpg"):
        match = pattern.match(nom_fichier)
        if match:
            tl, pl = match.groups()
            tl, pl = int(tl), int(pl)
            px, py = stereo(np.radians(tl), np.radians(pl)) # Calcul des coordonnées stéréo
            chemin_image = os.path.join(repertoire, nom_fichier)
            image = Image.open(chemin_image)
            w, h = image.size
            left = (w - img_width) / 2
            top = (h - img_height) / 2
            right = (w + img_width) / 2
            bottom = (h + img_height) / 2
            #left, top, right, bottom = int(left), int(top), int(right), int(bottom)
            image = Image.open(chemin_image).crop((left, top, right, bottom))
            pixels = np.array(image, dtype=np.float32) / 255.0


            images_info.append({
                "tl": tl,
                "pl": pl,
                "px": px,
                "py": py,
                "image": image,
                "pixels": pixels,
            })

# Exemple : affichage d'une info
for info in images_info[:5]:  # juste les 5 premières
    print(f"tl={info['tl']}, pl={info['pl']}, px={info['px']}, py={info['py']}")
# Out:
# tl=75, pl=345, px=0.7411809490095723, py=-0.198598836732448
# tl=75, pl=225, px=-0.5425821122771244, py=-0.5425821122771243
# tl=60, pl=252, px=-0.17841104369713806, py=-0.5490927320369364
# tl=30, pl=120, px=-0.13397459549759358, py=0.23205080632532074
# tl=45, pl=160, px=-0.3892334257113643, py=0.14166938114040184

# %%
images_info[2]['image']
# Out:
# <PIL.Image.Image image mode=RGB size=50x50>

# %%
fig, axes = plt.subplots(1, 5, figsize=(15, 5))
for i in range(5): axes[i].imshow(images_info[i]['pixels'])
plt.tight_layout()
plt.show()

# %% [markdown]
# # On trie la liste

# %%
images_info.sort(key=lambda d: (d["tl"], d["pl"]))

# %%
fig, axes = plt.subplots(1, 5, figsize=(15, 5))
for i in range(5): axes[i].imshow(images_info[i]['pixels'])
plt.tight_layout()
plt.show()

# %% [markdown]
# # Cette fois ci visualisation de l'oraganisation des texels en fonctin des positions stéréo

# %%
# On prend le pixel le plus au centre
texel_row = img_height // 2
texel_col = img_width // 2
texel_position_str = f"({texel_row}, {texel_col})" # Pour l'affichage
print(texel_position_str)
# Out:
# (25, 25)

# %%
# Visualiser l'organisation de la matrice 9*9 en fonction du tri
# D'abord tl pl puis px, py
texel_angles = []
texel_stereo = []

images_angles = copy.deepcopy(images_info) # Copie pour le tri par angles
images_stereo = copy.deepcopy(images_info) # Copie pour le tri par stéréographiques


# Appliquer les tris aux copies distinctes
images_angles.sort(key=lambda d: (d["tl"], d["pl"]))
images_stereo.sort(key=lambda d: (d["px"], d["py"]))


for ang, ste in zip(images_angles, images_stereo):
    # info["pixels"] est le tableau NumPy 30x30x3 pour l'image entière de cette configuration angulaire
    texel_rgb_a = ang["pixels"][texel_row, texel_col, :]
    texel_rgb_s = ste["pixels"][texel_row, texel_col, :]
    texel_angles.append(texel_rgb_a)
    texel_stereo.append(texel_rgb_s)

# Convertir la liste en tableau NumPy
texel_angles_np = np.array(texel_angles, dtype=np.float32) # Forme (81, 3)
texel_stereo_np = np.array(texel_stereo, dtype=np.float32) # Forme (81, 3)

# Remodeler en matrice 9x9x3
mat_a = (texel_angles_np * 255.0).clip(0, 255).reshape((9, 9, 3)).astype(np.uint8)
mat_s = (texel_stereo_np * 255.0).clip(0, 255).reshape((9, 9, 3)).astype(np.uint8)

fig, axes = plt.subplots(1, 2, figsize=(15, 5))
axes[0].imshow(mat_a)
axes[1].imshow(mat_s)
axes[0].set_title(f"Matrice 9x9 des valeurs RGB pour le texel {texel_position_str}\n(Organisée par tl pl)")
axes[1].set_title(f"Matrice 9x9 des valeurs RGB pour le texel {texel_position_str}\n(Organisée par px py)")
plt.show()

# %%
# Comme trier par les coordonnées stéréo sembl  plus adapté ici, c'est ce qu'on va choisir
images_info.sort(key=lambda d: (d["px"], d["py"]))
#images_info.sort(key=lambda d: (d["tl"], d["pl"]))
fig, axes = plt.subplots(1, 5, figsize=(15, 5))
for i in range(5): axes[i].imshow(images_info[i]['pixels'])
plt.tight_layout()
plt.show()

# %%
images_info[0]['pixels'][0, 0]
# Out:
# array([0.09019608, 0.12156863, 0.45490196], dtype=float32)

# %%
print("Premier pixel de la troisième image (R,G,B) :", images_info[2]['pixels'][0][0])
print("Nombre d'images importées:", len(images_info))
# Out:
# Premier pixel de la troisième image (R,G,B) : [0.08627451 0.1254902  0.4745098 ]
# Nombre d'images importées: 81

# %% [markdown]
# # Création du modèles

# %%
latent_dim = 8 # Dimension du bottleneck
num_channels = 3 # RGB
samples = len(images_info) # Nombre de configuration angulaires
matrix_H = 9
matrix_W = 9

input_shape = (matrix_H, matrix_W, num_channels)

# Definition
i = Input(shape=input_shape, name='encoder_input')

# Bloc 1 (Conv1D -> Conv2D, MaxPooling1D -> MaxPooling2D)
x = Conv2D(filters = 64, kernel_size=(3, 3), padding='same', activation='relu')(i)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Projection
x = Flatten()(x)
latent_output = Dense(latent_dim, name='latent_output')(x)

# Modèle
encoder_model_light = Model(inputs=i, outputs=latent_output, name="EncoderLight")
encoder_model_light.summary()
# Out:
# Model: "EncoderLight"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder_input (InputLayer)      │ (None, 9, 9, 3)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 9, 9, 64)       │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 9, 9, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_7 (Flatten)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ latent_output (Dense)           │ (None, 8)              │         8,200 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,248 (40.03 KB)
#  Trainable params: 10,120 (39.53 KB)
#  Non-trainable params: 128 (512.00 B)

# %%
# =================
# Decoder
# =================

# Paramètres
angle_dim = 2  # 2 pour lumière
input_dim = latent_dim + angle_dim  # 8 + 2 = 10

# Entrée
decoder_input = Input(shape=(input_dim,), name='decoder_input')

# 4 couches Fully Connected avec ReLU
x = Dense(106, activation='relu')(decoder_input)

x = Dense(106, activation='relu')(x)
x = Dense(106, activation='relu')(x)
x = Dense(106, activation='relu')(x)

# Sortie RGB (3 valeurs)
decoder_output = Dense(3, activation='linear', name='rgb_output')(x)

# Modèle
decoder_model = Model(inputs=decoder_input, outputs=decoder_output, name="Decoder")
decoder_model.summary()
# Out:
# Model: "Decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ decoder_input (InputLayer)      │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 106)            │         1,166 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 106)            │        11,342 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 106)            │        11,342 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 106)            │        11,342 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rgb_output (Dense)              │ (None, 3)              │           321 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 35,513 (138.72 KB)
#  Trainable params: 35,513 (138.72 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# =================
# VAE
# =================
view_light_input = Input(shape=(angle_dim,), name='view_light_input')
latent_vector = encoder_model_light(i)
decoder_input = Concatenate()([latent_vector, view_light_input])
vae_outputs = decoder_model(decoder_input)

vae = Model(inputs=[i, view_light_input], outputs=vae_outputs, name='VAE')
vae.summary()
# Out:
# Model: "VAE"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ encoder_input       │ (None, 9, 9, 3)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EncoderLight        │ (None, 8)         │     10,248 │ encoder_input[0]… │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ view_light_input    │ (None, 2)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 10)        │          0 │ EncoderLight[0][… │
# │ (Concatenate)       │                   │            │ view_light_input… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Decoder             │ (None, 3)         │     35,513 │ concatenate_7[0]… │
# │ (Functional)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 45,761 (178.75 KB)
#  Trainable params: 45,633 (178.25 KB)
#  Non-trainable params: 128 (512.00 B)

# %%
# --- L2 Loss ---
def custom_reconstruction_loss(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true - y_pred))

# %% [markdown]
# # Compilation et entraînement
# Sur un seul texel pour commencer

# %%
# on prend toutes les images
image_stack = np.stack([info["pixels"] for info in images_info], axis=0)
# image_stack.shape = (N_images, height, width, 3)

# %%
# on fait de même avec les angles
tl_stack = np.stack([info["tl"] for info in images_info], axis=0)
pl_stack = np.stack([info["pl"] for info in images_info], axis=0)

# et pour les positions stéréo
px_stack = np.stack([info["px"] for info in images_info], axis=0)
py_stack = np.stack([info["py"] for info in images_info], axis=0)

# %%
# Préparation des données

# Choisir UN texel
texel_position = (0, 0)
texel_observations = image_stack[:, texel_position[0], texel_position[1]] # (samples, num_channels) ex: (81, 3)

padded_observations = np.zeros((matrix_H * matrix_W, num_channels))
padded_observations[:len(texel_observations)] = texel_observations

input_train_batch_2d = padded_observations.reshape((1, matrix_H, matrix_W, num_channels))
target_rgb_train = texel_observations  # (81, 3)
light_dirs = np.stack([px_stack, py_stack], axis=1) # Forme (81, 2)

# %%
custom_optimizer = Adam(learning_rate=0.01) # Adam est une version améliorée de la descente de gradient stochastique, par défaut on avait 0.001
vae.compile(custom_optimizer, loss=lambda y_true, y_pred: custom_reconstruction_loss(y_true, y_pred))

history_vae = vae.fit([np.repeat(input_train_batch_2d, samples, axis=0), light_dirs], target_rgb_train,
        epochs=200, batch_size=5, validation_split=0.2)
# Out:
# Epoch 1/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4339 - val_loss: 0.0753
# Epoch 2/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0101 - val_loss: 0.0258
# Epoch 3/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0176 - val_loss: 0.0373
# Epoch 4/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0111 - val_loss: 0.0643
# Epoch 5/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0121 - val_loss: 0.0122
# Epoch 6/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0132 - val_loss: 0.0117
# Epoch 7/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - val_loss: 0.0209
# Epoch 8/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0178 - val_loss: 0.0190
# Epoch 9/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0077 - val_loss: 0.0257
# Epoch 10/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0110 - val_loss: 0.0082
# Epoch 11/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096 - val_loss: 0.0080
# Epoch 12/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0117 - val_loss: 0.0065
# Epoch 13/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 14/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 15/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0076 - val_loss: 0.0079
# Epoch 16/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0087 - val_loss: 0.0066
# Epoch 17/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0079 - val_loss: 0.0079
# Epoch 18/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - val_loss: 0.0069
# Epoch 19/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - val_loss: 0.0072
# Epoch 20/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0073
# Epoch 21/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096 - val_loss: 0.0088
# Epoch 22/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0153
# Epoch 23/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0085 - val_loss: 0.0137
# Epoch 24/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0100 - val_loss: 0.0090
# Epoch 25/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0075 - val_loss: 0.0100
# Epoch 26/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079 - val_loss: 0.0237
# Epoch 27/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042 - val_loss: 0.0150
# Epoch 28/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044 - val_loss: 0.0234
# Epoch 29/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - val_loss: 0.0249
# Epoch 30/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - val_loss: 0.0204
# Epoch 31/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046 - val_loss: 0.0175
# Epoch 32/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0033 - val_loss: 0.0200
# Epoch 33/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035 - val_loss: 0.0183
# Epoch 34/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - val_loss: 0.0185
# Epoch 35/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - val_loss: 0.0076
# Epoch 36/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - val_loss: 0.0297
# Epoch 37/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - val_loss: 0.0337
# Epoch 38/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056 - val_loss: 0.0261
# Epoch 39/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - val_loss: 0.0356
# Epoch 40/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - val_loss: 0.0318
# Epoch 41/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - val_loss: 0.0177
# Epoch 42/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - val_loss: 0.0261
# Epoch 43/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - val_loss: 0.0262
# Epoch 44/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0291
# Epoch 45/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - val_loss: 0.0227
# Epoch 46/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0131
# Epoch 47/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0209
# Epoch 48/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - val_loss: 0.0317
# Epoch 49/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4415e-04 - val_loss: 0.0094
# Epoch 50/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - val_loss: 0.0062
# Epoch 51/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - val_loss: 0.0105
# Epoch 52/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1795e-04 - val_loss: 0.0118
# Epoch 53/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0100
# Epoch 54/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - val_loss: 0.0055
# Epoch 55/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0065
# Epoch 56/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1456e-04 - val_loss: 0.0037
# Epoch 57/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6341e-04 - val_loss: 0.0049
# Epoch 58/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4165e-04 - val_loss: 0.0093
# Epoch 59/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3377e-04 - val_loss: 0.0033
# Epoch 60/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2491e-04 - val_loss: 0.0023
# Epoch 61/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7320e-04 - val_loss: 0.0076
# Epoch 62/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2656e-04 - val_loss: 0.0022
# Epoch 63/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5193e-04 - val_loss: 0.0033
# Epoch 64/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5435e-04 - val_loss: 0.0023
# Epoch 65/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0382e-04 - val_loss: 0.0039
# Epoch 66/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2829e-04 - val_loss: 0.0033
# Epoch 67/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3784e-04 - val_loss: 0.0033
# Epoch 68/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5830e-04 - val_loss: 0.0031
# Epoch 69/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9009e-05 - val_loss: 0.0030
# Epoch 70/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0091e-05 - val_loss: 0.0020
# Epoch 71/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9242e-05 - val_loss: 0.0033
# Epoch 72/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3423e-05 - val_loss: 0.0027
# Epoch 73/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0839e-05 - val_loss: 0.0027
# Epoch 74/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8061e-05 - val_loss: 0.0022
# Epoch 75/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6669e-05 - val_loss: 0.0025
# Epoch 76/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8309e-05 - val_loss: 0.0029
# Epoch 77/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2474e-04 - val_loss: 0.0016
# Epoch 78/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5249e-05 - val_loss: 0.0020
# Epoch 79/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5562e-05 - val_loss: 0.0036
# Epoch 80/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5551e-05 - val_loss: 0.0011
# Epoch 81/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6783e-04 - val_loss: 0.0026
# Epoch 82/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0603e-04 - val_loss: 0.0019
# Epoch 83/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8281e-05 - val_loss: 0.0026
# Epoch 84/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1727e-05 - val_loss: 0.0022
# Epoch 85/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8185e-05 - val_loss: 0.0017
# Epoch 86/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2827e-05 - val_loss: 0.0011
# Epoch 87/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9053e-05 - val_loss: 0.0019
# Epoch 88/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7188e-05 - val_loss: 0.0023
# Epoch 89/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4015e-05 - val_loss: 0.0014
# Epoch 90/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4481e-05 - val_loss: 0.0017
# Epoch 91/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1381e-05 - val_loss: 0.0019
# Epoch 92/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5452e-05 - val_loss: 0.0019
# Epoch 93/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8143e-05 - val_loss: 0.0022
# Epoch 94/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1187e-05 - val_loss: 0.0018
# Epoch 95/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7817e-05 - val_loss: 0.0021
# Epoch 96/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3021e-05 - val_loss: 0.0014
# Epoch 97/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7718e-05 - val_loss: 0.0018
# Epoch 98/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0376e-05 - val_loss: 0.0019
# Epoch 99/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0091e-05 - val_loss: 0.0022
# Epoch 100/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7053e-05 - val_loss: 0.0019
# Epoch 101/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1467e-05 - val_loss: 0.0017
# Epoch 102/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9055e-05 - val_loss: 8.3690e-04
# Epoch 103/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1034e-04 - val_loss: 0.0018
# Epoch 104/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1786e-05 - val_loss: 0.0023
# Epoch 105/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3351e-05 - val_loss: 0.0019
# Epoch 106/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7256e-05 - val_loss: 0.0011
# Epoch 107/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5399e-05 - val_loss: 0.0013
# Epoch 108/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9190e-05 - val_loss: 0.0018
# Epoch 109/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4660e-05 - val_loss: 0.0016
# Epoch 110/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4400e-05 - val_loss: 0.0021
# Epoch 111/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8894e-05 - val_loss: 0.0016
# Epoch 112/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1797e-05 - val_loss: 0.0020
# Epoch 113/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8488e-05 - val_loss: 0.0019
# Epoch 114/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8903e-05 - val_loss: 0.0015
# Epoch 115/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4751e-05 - val_loss: 0.0018
# Epoch 116/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4361e-05 - val_loss: 0.0017
# Epoch 117/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2316e-05 - val_loss: 0.0018
# Epoch 118/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4320e-05 - val_loss: 0.0016
# Epoch 119/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9406e-05 - val_loss: 0.0018
# Epoch 120/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3350e-05 - val_loss: 0.0013
# Epoch 121/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4223e-05 - val_loss: 0.0018
# Epoch 122/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5439e-05 - val_loss: 0.0015
# Epoch 123/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9129e-05 - val_loss: 0.0017
# Epoch 124/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0587e-05 - val_loss: 0.0014
# Epoch 125/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3534e-05 - val_loss: 0.0015
# Epoch 126/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6857e-05 - val_loss: 0.0017
# Epoch 127/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9164e-05 - val_loss: 0.0012
# Epoch 128/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6487e-05 - val_loss: 0.0016
# Epoch 129/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2453e-05 - val_loss: 0.0019
# Epoch 130/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8333e-05 - val_loss: 0.0012
# Epoch 131/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8321e-05 - val_loss: 0.0022
# Epoch 132/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1928e-04 - val_loss: 0.0014
# Epoch 133/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4291e-04 - val_loss: 0.0024
# Epoch 134/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5124e-04 - val_loss: 0.0022
# Epoch 135/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0258e-04 - val_loss: 0.0013
# Epoch 136/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1261e-04 - val_loss: 0.0018
# Epoch 137/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4582e-04 - val_loss: 0.0022
# Epoch 138/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5281e-04 - val_loss: 6.9387e-04
# Epoch 139/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3386e-04 - val_loss: 0.0018
# Epoch 140/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0849e-04 - val_loss: 8.2750e-04
# Epoch 141/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0007e-04 - val_loss: 0.0078
# Epoch 142/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2818e-04 - val_loss: 0.0018
# Epoch 143/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - val_loss: 0.0043
# Epoch 144/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7553e-04 - val_loss: 0.0014
# Epoch 145/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.0373e-04 - val_loss: 0.0172
# Epoch 146/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 147/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - val_loss: 0.0365
# Epoch 148/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - val_loss: 0.0041
# Epoch 149/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - val_loss: 0.0438
# Epoch 150/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6761e-04 - val_loss: 0.0187
# Epoch 151/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - val_loss: 0.0065
# Epoch 152/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0333
# Epoch 153/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - val_loss: 0.0360
# Epoch 154/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6007e-04 - val_loss: 0.0320
# Epoch 155/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5512e-04 - val_loss: 0.0383
# Epoch 156/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9988e-04 - val_loss: 0.0250
# Epoch 157/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9492e-04 - val_loss: 0.0108
# Epoch 158/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4094e-04 - val_loss: 0.0131
# Epoch 159/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1717e-04 - val_loss: 0.0028
# Epoch 160/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0843e-04 - val_loss: 0.0034
# Epoch 161/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3508e-04 - val_loss: 0.0012
# Epoch 162/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0078e-05 - val_loss: 0.0028
# Epoch 163/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0468e-05 - val_loss: 9.2097e-04
# Epoch 164/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7404e-05 - val_loss: 9.1886e-04
# Epoch 165/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2206e-05 - val_loss: 9.6189e-04
# Epoch 166/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9370e-05 - val_loss: 6.5102e-04
# Epoch 167/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9097e-05 - val_loss: 9.0620e-04
# Epoch 168/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5209e-05 - val_loss: 3.1871e-04
# Epoch 169/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7091e-05 - val_loss: 3.6073e-04
# Epoch 170/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7158e-05 - val_loss: 2.2316e-04
# Epoch 171/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4079e-05 - val_loss: 0.0010
# Epoch 172/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7584e-05 - val_loss: 4.7211e-04
# Epoch 173/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4640e-05 - val_loss: 3.7702e-04
# Epoch 174/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3872e-05 - val_loss: 2.7204e-04
# Epoch 175/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8701e-05 - val_loss: 1.5464e-04
# Epoch 176/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9561e-05 - val_loss: 2.9306e-04
# Epoch 177/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1084e-05 - val_loss: 1.5820e-04
# Epoch 178/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8436e-05 - val_loss: 3.2773e-04
# Epoch 179/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0634e-05 - val_loss: 2.3028e-04
# Epoch 180/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3867e-05 - val_loss: 3.3232e-04
# Epoch 181/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2946e-05 - val_loss: 3.1962e-04
# Epoch 182/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8832e-05 - val_loss: 2.2268e-04
# Epoch 183/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9919e-05 - val_loss: 3.5785e-04
# Epoch 184/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6340e-05 - val_loss: 2.6202e-04
# Epoch 185/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9724e-05 - val_loss: 6.9629e-04
# Epoch 186/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6093e-05 - val_loss: 2.4274e-04
# Epoch 187/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.0283e-05 - val_loss: 2.8271e-04
# Epoch 188/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4159e-04 - val_loss: 2.1681e-04
# Epoch 189/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4321e-04 - val_loss: 5.4946e-04
# Epoch 190/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6872e-04 - val_loss: 4.2409e-04
# Epoch 191/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2738e-05 - val_loss: 4.4585e-04
# Epoch 192/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5219e-05 - val_loss: 1.5698e-04
# Epoch 193/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3442e-05 - val_loss: 3.4173e-04
# Epoch 194/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5458e-05 - val_loss: 4.4592e-04
# Epoch 195/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2961e-05 - val_loss: 2.3348e-04
# Epoch 196/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6295e-05 - val_loss: 2.6050e-04
# Epoch 197/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4099e-05 - val_loss: 2.0915e-04
# Epoch 198/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3713e-05 - val_loss: 1.8934e-04
# Epoch 199/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0757e-05 - val_loss: 2.3420e-04
# Epoch 200/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0394e-05 - val_loss: 1.7450e-04

# %%
# Evaluer l'apprentissage d'un modèle --Code: Patrick Reuter--
def montrerCourbesApprentissage(history):
    #list all data in history
    print(history.history.keys())

    plt.plot(history.history['loss'][10:], label="Training loss")
    plt.plot(history.history['val_loss'][10:], label="Validation loss")

    plt.title("Données d'entrâinement (FC)")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()

montrerCourbesApprentissage(history_vae)
# Out:
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# # Prédicitions d'un texel avec une configuration spécifique

# %%
index = 3
light_direction =light_dirs[index]

latent_vector = encoder_model_light.predict(input_train_batch_2d)[0]  # (8,)

# Prédire pour une direction spécifique (par exemple view_light_train[0])
decoder_input = np.concatenate([latent_vector, light_direction])[np.newaxis, :]
predicted_rgb = decoder_model.predict(decoder_input)  # (1, 3)
print("Predicted RGB:", predicted_rgb, "Original", target_rgb_train[index])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted RGB: [[0.09463859 0.13190696 0.4900726 ]] Original [0.09411765 0.12941177 0.49411765]

# %% [markdown]
# # Prédiction avec carte des vecteurs latents

# %%
# Générer carte latente composée de tous les vecteurs latent par texel
latent_map = np.zeros((img_height, img_width, latent_dim), dtype=np.float32)

for y in range(img_height):
    for x in range(img_width):
        texel_rgb_values_all_configs = image_stack[:, y, x, :] # (num_angles, 3)
        input_encoder_for_texel = texel_rgb_values_all_configs.reshape((matrix_H, matrix_W, num_channels)) # (9, 9, 3)
        
        # Ajouter une dimension de batch (batch_size=1)
        input_encoder_for_texel_batch = np.expand_dims(input_encoder_for_texel, axis=0) # (1, 9, 9, 3)

        # Prédire le vecteur latent
        latent_vector = encoder_model_light.predict(input_encoder_for_texel_batch, verbose=0)[0] # (8,)
        latent_map[y, x] = latent_vector

print(f"Forme de la carte latente: {latent_map.shape}")
# Out:
# Forme de la carte latente: (50, 50, 8)

# %%
def predict_image_from_latent(latent_map, light_direction_2d):
    """
    latent_map: (H, W, 8) carte des vecteurs latents
    light_direction_2d: (2,) stéréographique [lx, ly] (pour la lumière)
    """
    H, W, latent_dim = latent_map.shape
    
    # Le décodeur attend latent_dim + 2 dimensions
    decoder_input_dim_expected = latent_dim + 2 # Ici, 8 + 2 = 10

    # Flatten latent map
    latent_flat = latent_map.reshape(-1, latent_dim)  # (H*W, 8)

    # Répéter la direction de lumière pour tous les texels
    # Assurez-vous que light_direction_2d est bien de forme (2,)
    dir_repeated = np.repeat(light_direction_2d[np.newaxis, :], H * W, axis=0)  # (H*W, 2)

    # Concaténer
    decoder_input = np.concatenate([latent_flat, dir_repeated], axis=1)  # (H*W, 10)

    # Vérification (optionnel mais utile pour le debug)
    if decoder_input.shape[1] != decoder_input_dim_expected:
        raise ValueError(f"La dimension d'entrée du décodeur ne correspond pas. Attendu: {decoder_input_dim_expected}, Trouvé: {decoder_input.shape[1]}")

    # Prédiction
    predicted_rgb_flat = decoder_model.predict(decoder_input, verbose=0)  # (H*W, 3)
    predicted_image = (predicted_rgb_flat * 255.0).clip(0, 255).reshape(H, W, 3).astype(np.uint8)

    return predicted_image

# %%
# Choix d'une image à prédire
index = 67

direction = light_dirs[index]  # (2,)
predicted_image = predict_image_from_latent(latent_map, direction)

plt.imshow(predicted_image)
plt.title(f"Image prédite pour view_light_train[{index}]")
plt.axis('off')
plt.show()

# %%
def show_comparison(predicted_image, ground_truth_image):
    # Différence absolue par pixel
    predicted_image_float = predicted_image.astype(np.float32) / 255.0
    ground_truth_image_float = ground_truth_image.astype(np.float32) / 255.0
    mse = np.mean(np.square(predicted_image_float - ground_truth_image_float))

    # Affichage
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    axs[0].imshow(predicted_image)
    axs[0].set_title("Image prédite")
    axs[0].axis('off')

    axs[1].imshow(ground_truth_image)
    axs[1].set_title("Image réelle")
    axs[1].axis('off')

    # Affichage de la valeur MSE au lieu de l'image de différence
    axs[2].axis('off')
    axs[2].text(0.5, 0.5, f"MSE: {mse:.3f}", horizontalalignment='center', verticalalignment='center', fontsize=18, color='black', transform=axs[2].transAxes)
    axs[2].set_title("Erreur de Reconstruction")


    plt.tight_layout()
    plt.show()

# %%
# Afficher la comparaison entre les images
index = 70
direction = light_dirs[index]
predicted_image = predict_image_from_latent(latent_map, direction)
ground_truth_image = image_stack[index]  # (H, W, 3)

show_comparison(predicted_image, ground_truth_image)

# %%
# Afficher la comparaison entre les images
for i in range(1, 81, 9):
    direction = light_dirs[i]
    predicted_image = predict_image_from_latent(latent_map, direction)
    ground_truth_image = image_stack[index]  # (H, W, 3)

    show_comparison(predicted_image, ground_truth_image)
